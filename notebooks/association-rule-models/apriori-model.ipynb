# %% [markdown]
# # Apriori Model

# %% [markdown]
# ## Import the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os.path

# %% [markdown]
# ## Load the dataset

# %%
raw_data_file_path = '/Users/vishalsaxena/Documents/DS_Workspace/udemy_ml_algo_python/data/raw'
dataset = pd.read_csv(os.path.join(raw_data_file_path, 'Market_Basket_Optimisation.csv'), header=None)
dataset
# Out:
#                  0                  1            2                 3   \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs               NaN
# 2           chutney                NaN          NaN               NaN
# 3            turkey            avocado          NaN               NaN
# 4     mineral water               milk   energy bar  whole wheat rice
# ...             ...                ...          ...               ...
# 7496         butter         light mayo  fresh bread               NaN
# 7497        burgers  frozen vegetables         eggs      french fries
# 7498        chicken                NaN          NaN               NaN
# 7499       escalope          green tea          NaN               NaN
# 7500           eggs    frozen smoothie  yogurt cake    low fat yogurt
#
#                 4                 5     6               7             8   \
# ...

# %% [markdown]
# ## Data Preprocessing

# %%
transactions = []
for i in range(len(dataset)):
    transaction = [str(item) for item in dataset.iloc[i] if pd.notna(item)]
    transactions.append(transaction)
# transactions

# %% [markdown]
# ## Training the Apriori model on the dataset

# %%
from apyori import apriori
rules = apriori(transactions=transactions, min_support=.003, min_confidence=0.2, min_lift=3, min_length=2, max_length=2)
rules
# Out:
# <generator object apriori at 0x15b03f0d0>

# %% [markdown]
# ## Visualizing the results

# %% [markdown]
# ### Displaying the 1st results from rules

# %%
results = list(rules)

# %%
results
# Out:
# [RelationRecord(items=frozenset({'light cream', 'chicken'}), support=0.004532728969470737, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'chicken'}), confidence=0.29059829059829057, lift=4.84395061728395)]),
#  RelationRecord(items=frozenset({'escalope', 'mushroom cream sauce'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'escalope'}), confidence=0.3006993006993007, lift=3.790832696715049)]),
#  RelationRecord(items=frozenset({'escalope', 'pasta'}), support=0.005865884548726837, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'escalope'}), confidence=0.3728813559322034, lift=4.700811850163794)]),
# ...

# %%
# transactions = []
# for item in dataset.index:
#     transactions.append(list(dataset.iloc[item,:].values))
# transactions
for result in results:
    print(result[2][0][0])
    break
# Out:
# frozenset({'light cream'})

# %% [markdown]
# ## Putting the data in dataframe

# %%
def inspect(results):
    lhs = [tuple(result[2][0][0])[0] for result in results]
    rhs = [tuple(result[2][0][1])[0] for result in results]
    supports = [result[1] for result in results]
    confidence = [result[2][0][2] for result in results]
    lifts = [result[2][0][3] for result in results]
    return list(zip(lhs, rhs, supports, confidence, lifts))
inspect(results)
# Out:
# [('light cream',
#   'chicken',
#   0.004532728969470737,
#   0.29059829059829057,
#   4.84395061728395),
#  ('mushroom cream sauce',
#   'escalope',
#   0.005732568990801226,
#   0.3006993006993007,
#   3.790832696715049),
#  ('pasta',
#   'escalope',
#   0.005865884548726837,
#   0.3728813559322034,
#   4.700811850163794),
#  ('fromage blanc',
#   'honey',
#   0.003332888948140248,
#   0.2450980392156863,
#   5.164270764485569),
#  ('herb & pepper',
#   'ground beef',
#   0.015997866951073192,
#   0.3234501347708895,
#   3.2919938411349285),
#  ('tomato sauce',
#   'ground beef',
#   0.005332622317024397,
#   0.3773584905660377,
#   3.840659481324083),
#  ('light cream',
#   'olive oil',
#   0.003199573390214638,
#   0.20512820512820515,
#   3.1147098515519573),
#  ('whole wheat pasta',
#   'olive oil',
#   0.007998933475536596,
#   0.2714932126696833,
#   4.122410097642296),
#  ('pasta',
#   'shrimp',
#   0.005065991201173177,
#   0.3220338983050847,
#   4.506672147735896)]

# %% [markdown]
# ## Display in result set in non-sorted

# %%
result_df = pd.DataFrame(inspect(results), columns = ['Left Hand Side', 'Right Hand Side', 'Support', 
                                                      'Confidence', 'Lift'])
result_df
# Out:
#          Left Hand Side Right Hand Side   Support  Confidence      Lift
# 0           light cream         chicken  0.004533    0.290598  4.843951
# 1  mushroom cream sauce        escalope  0.005733    0.300699  3.790833
# 2                 pasta        escalope  0.005866    0.372881  4.700812
# 3         fromage blanc           honey  0.003333    0.245098  5.164271
# 4         herb & pepper     ground beef  0.015998    0.323450  3.291994
# 5          tomato sauce     ground beef  0.005333    0.377358  3.840659
# 6           light cream       olive oil  0.003200    0.205128  3.114710
# 7     whole wheat pasta       olive oil  0.007999    0.271493  4.122410
# 8                 pasta          shrimp  0.005066    0.322034  4.506672

# %% [markdown]
# ## Displaying the result set in sorted

# %%
result_df.sort_values(by='Lift', ascending=False)
# Out:
#          Left Hand Side Right Hand Side   Support  Confidence      Lift
# 3         fromage blanc           honey  0.003333    0.245098  5.164271
# 0           light cream         chicken  0.004533    0.290598  4.843951
# 2                 pasta        escalope  0.005866    0.372881  4.700812
# 8                 pasta          shrimp  0.005066    0.322034  4.506672
# 7     whole wheat pasta       olive oil  0.007999    0.271493  4.122410
# 5          tomato sauce     ground beef  0.005333    0.377358  3.840659
# 1  mushroom cream sauce        escalope  0.005733    0.300699  3.790833
# 4         herb & pepper     ground beef  0.015998    0.323450  3.291994
# 6           light cream       olive oil  0.003200    0.205128  3.114710
